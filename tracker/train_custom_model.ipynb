# %% [markdown]
# # Run in Colab

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.0/112.6 GB disk)

# %%
# !nvidia-smi
# Out:
# Fri Jan 31 17:18:49 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8             12W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# %cd {HOME}
# Load this .zip file manually and move to content/datasets
# This .zip file contains the images and labels used for training.
# !unzip data.zip
# Out:
# /content
# Archive:  data.zip
#    creating: data/
#    creating: data/test/
#    creating: data/test/images/
#   inflating: data/test/images/CAGE_220520_HB45009_exploration_IB.mp4_frame900.jpg
#   inflating: data/test/images/CAGE_220520_HB45009_exploration_IB.mp4_frame200.jpg
#   inflating: data/test/images/CAGE_220520_HB45009_exploration_IB.mp4_frame1800.jpg
#   inflating: data/test/images/CAGE_220520_HB45009_exploration_IB.mp4_frame800.jpg
#   inflating: data/test/images/CAGE_220520_HB45009_exploration_IB.mp4_frame3000.jpg
#   inflating: data/test/images/CAGE_220520_HB45009_exploration_IB.mp4_frame1600.jpg
#   inflating: data/test/images/CAGE_220520_HB45009_exploration_IB.mp4_frame600.jpg
#   inflating: data/test/images/CAGE_220520_HB45009_exploration_IB.mp4_frame500.jpg
#   inflating: data/test/images/CAGE_220520_HB45009_exploration_IB.mp4_frame1500.jpg
#   inflating: data/test/images/CAGE_220520_HB45009_exploration_IB.mp4_frame400.jpg
# ...

# %%
# Train YOLO11n on custom dataset.
# Set data.yaml path attribute first.
# !yolo task=detect mode=train model=yolo11n.pt data={HOME}/data/data.yaml epochs=60 imgsz=1280 plots=True
# Out:
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
