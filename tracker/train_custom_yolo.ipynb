# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.82 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 35.5/112.6 GB disk)

# %%
# !nvidia-smi
# Out:
# Sun Mar  2 13:02:04 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8              9W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# Load data.zip file manually to colab first. The file needs to have specific structure. See yolo instructions.

# %%
# Unzip data.zip
# !mkdir datasets
# !mv data.zip {HOME}/datasets/
# %cd datasets
# !unzip data.zip
# Out:
# Archive:  /content/datasets/data.zip
#    creating: data/
#   inflating: data/data.yaml
#    creating: data/train/
#    creating: data/train/images/
#   inflating: data/train/images/CAGE_020720_HA70343_exploration_IB.mp4_frame0.jpg
#   inflating: data/train/images/CAGE_020720_HA70343_exploration_IB.mp4_frame10200.jpg
#   inflating: data/train/images/CAGE_020720_HA70343_exploration_IB.mp4_frame10800.jpg
#   inflating: data/train/images/CAGE_020720_HA70343_exploration_IB.mp4_frame11400.jpg
#   inflating: data/train/images/CAGE_020720_HA70343_exploration_IB.mp4_frame1200.jpg
#   inflating: data/train/images/CAGE_020720_HA70343_exploration_IB.mp4_frame12600.jpg
#   inflating: data/train/images/CAGE_020720_HA70343_exploration_IB.mp4_frame13200.jpg
#   inflating: data/train/images/CAGE_020720_HA70343_exploration_IB.mp4_frame13800.jpg
#   inflating: data/train/images/CAGE_020720_HA70343_exploration_IB.mp4_frame15000.jpg
# ...

# %%
# Train YOLO11n
# !yolo task=detect mode=train model=yolo11n.pt data={HOME}/datasets/data/data.yaml epochs=100 imgsz=1280 plots=False
# Out:
# ...
# 100% 5.35M/5.35M [00:00<00:00, 307MB/s]
# Ultralytics 8.3.82 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# asd
